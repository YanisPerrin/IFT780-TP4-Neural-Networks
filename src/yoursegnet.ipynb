# %% [markdown]
# # YourSegNet

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp -r drive/MyDrive/IFT780/Tp4/* .

# %%
# !pip install -r requirements.txt

# %%
cd src/

# %%
# !python3 train.py --model=yourSegNet --num-epoch=40 --batch_size=4 --lr=0.01 --loss=DiceCE --save_checkpoint
# Out:
# Checkpoints will be saved!
# Data augmentation NOT activated!
# Training YourSegNet on acdc for 40 epochs
# Epoch: 1 of 40
# 100% 320/320 [02:08<00:00,  2.49it/s, Train loss=1.26, train_acc=0.145]
# Validation loss 0.940
# Validation accuracy 0.181
# best_val_acc: 0.0 | val_acc: 0.18102911073300573
# Saving model...
# Epoch: 2 of 40
# 100% 320/320 [02:11<00:00,  2.44it/s, Train loss=0.589, train_acc=0.484]
# Validation loss 0.567
# Validation accuracy 0.535
# best_val_acc: 0.18102911073300573 | val_acc: 0.5350253954529762
# Saving model...
# Epoch: 3 of 40
# 100% 320/320 [02:13<00:00,  2.40it/s, Train loss=0.431, train_acc=0.621]
# Validation loss 0.468
# Validation accuracy 0.607
# best_val_acc: 0.5350253954529762 | val_acc: 0.6072262186143134
# Saving model...
# Epoch: 4 of 40
# 100% 320/320 [02:13<00:00,  2.39it/s, Train loss=0.357, train_acc=0.685]
# Validation loss 0.332
# Validation accuracy 0.707
# best_val_acc: 0.6072262186143134 | val_acc: 0.706907705300384
# ...

# %%
# !python3 train.py --model=yourSegNet --predict=checkpoints/YourSegNet_82.pt

# %%
from IPython.display import Image, display

listOfImageNames = ['fig1.png', 'fig2.png', 'fig3.png', 'fig4.png']

for imageName in listOfImageNames:
    display(Image(filename=imageName))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-1ead9d07b63e> in <cell line: 5>()
#       4
#       5 for imageName in listOfImageNames:
# ----> 6     display(Image(filename=imageName))
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...
