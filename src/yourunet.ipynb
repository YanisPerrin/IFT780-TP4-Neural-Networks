# %% [markdown]
# # YourSegNet

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp -r drive/MyDrive/IFT780/tp4/* .

# %%
# !pip install -r requirements.txt

# %%
cd src/

# %% [markdown]
# ## Entraînement de YourSegNet

# %%
# !python3 train.py --model=yourUNet --num-epochs=40 --batch_size=4 --lr=0.01 --save_checkpoint --loss="DiceCE"
# Out:
# Checkpoints will be saved!
# Data augmentation NOT activated!
# Using mps.
# Training YourUNet on acdc for 40 epochs
# Epoch: 1 of 40
# 100%|██████| 320/320 [02:34<00:00,  2.08it/s, Train loss=1.39, train_acc=0.0528]
# Validation loss 1.082
# Validation accuracy 0.069
# best_val_acc: 0.0 | val_acc: 0.06852273534362514
# Saving model...
# Epoch: 2 of 40
# 100%|███████| 320/320 [02:31<00:00,  2.11it/s, Train loss=0.86, train_acc=0.258]
# Validation loss 1.045
# Validation accuracy 0.210
# best_val_acc: 0.06852273534362514 | val_acc: 0.20982413552701473
# Saving model...
# Epoch: 3 of 40
# 100%|███████| 320/320 [02:33<00:00,  2.09it/s, Train loss=0.66, train_acc=0.424]
# Validation loss 0.660
# Validation accuracy 0.453
# best_val_acc: 0.20982413552701473 | val_acc: 0.45258866250514984
# Saving model...
# Epoch: 4 of 40
# 100%|██████| 320/320 [02:30<00:00,  2.12it/s, Train loss=0.535, train_acc=0.534]
# Validation loss 0.730
# Validation accuracy 0.396
# ...

# %%
# !python3 train.py --model=yourUNet --predict=checkpoints/YourUNet_DiceCE_82.pt
# Out:
# Checkpoints will NOT be saved!
# Data augmentation NOT activated!
# Using mps.
# Using mps.
# predicting the mask of a randomly selected image from test set
# Figure(1000x1000)
# Figure(1000x1000)
# Figure(1000x1000)

# %%
from IPython.display import Image, display

listOfImageNames = ['fig1.png', 'fig2.png', 'fig3.png', 'fig4.png']

for imageName in listOfImageNames:
    display(Image(filename=imageName))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 6
#       3 listOfImageNames = ['fig1.png', 'fig2.png', 'fig3.png', 'fig4.png']
#       5 for imageName in listOfImageNames:
# ----> 6     display(Image(filename=imageName))
#
# File /Library/Python/3.9/site-packages/IPython/core/display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# File /Library/Python/3.9/site-packages/IPython/core/display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
#     324 elif self.metadata is None:
# ...
